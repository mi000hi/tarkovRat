# %%
import apiRequestTest as api

from time import sleep
import pandas as pd
import tkinter as tk

# %%
path_data = './data/'

# %%
def items_dict_to_df(all_items):
    all_items_df = pd.DataFrame(columns=['name', 'id', 'width', 'height', 'icon_width', 'icon_height', 'features', 'fleaMarket', 'flea_avg48', 'flea_ch48percent', 'prapor', 'therapist', 'fence', 'skier', 'peacekeeper', 'mechanic', 'ragman', 'jaeger'], index=range(len(all_items)))

    # iterate over all items
    for index in range(len(all_items)):
        all_items_df.iloc[index]['name'] = all_items[index].get('name')
        all_items_df.iloc[index]['id'] = all_items[index].get('id')
        all_items_df.iloc[index]['width'] = all_items[index].get('width')
        all_items_df.iloc[index]['height'] = all_items[index].get('height')
        all_items_df.iloc[index]['flea_avg48'] = all_items[index].get('avg24hPrice')
        all_items_df.iloc[index]['flea_ch48percent'] = all_items[index].get('changeLast48hPercent')

        # iterate over all traders that can buy the item
        for offer in all_items[index].get('sellFor'):
            trader = offer.get('source')
            price  = offer.get('price')
            all_items_df.iloc[index][trader] = price
    
    return all_items_df

# %%
# create the items dataframe
all_items_dict = api.getAllItemsPrices()

# %%
all_items_df   = items_dict_to_df(all_items_dict)

# %%
# save dataframe as csv
all_items_df.to_csv(path_data + 'all_items.csv', index=False)

# %%
# load dataframe from csv
all_items_df = pd.read_csv(path_data + 'all_items.csv')

# %%
all_items_df
# Out:
#                                               name                        id  \
# 0                  Colt M4A1 5.56x45 assault rifle  5447a9cd4bdc2dbd208b4567
# 1                5.56x45mm M855 ammo pack (30 pcs)  5447ac644bdc2d6c208b4567
# 2                       Factory emergency exit key  5448ba0b4bdc2d02308b456c
# 3                         Makarov PM 9x18PM pistol  5448bd6b4bdc2dfc2f8b4569
# 4                               RGD-5 hand grenade  5448be9a4bdc2dfd2f8b456a
# ...                                            ...                       ...
# 2718                     Oakley SI Batwolf glasses  62a61c988ec41a51b34758d5
# 2719                        Rogue USEC barrack key  62a9cb937377a65d7b070cef
# 2720                                        Dogtag  customdogtags12345678910
# 2721                      Glock 17 9x19 pistol PS9  glock17ps900000000000001
# 2722  Mosin 7.62x54R bolt-action rifle (Sniper) PU  mosinscopedbarter0000001
#
#      width height icon_width icon_height features fleaMarket flea_avg48  \
# 0        1      1        NaN         NaN      NaN      55000      80823
# 1        1      1        NaN         NaN      NaN      10000          0
# 2        1      1        NaN         NaN      NaN      66888      81146
# 3        2      1        NaN         NaN      NaN       6000       8814
# 4        1      1        NaN         NaN      NaN      11821      13412
# ...    ...    ...        ...         ...      ...        ...        ...
# 2718     2      1        NaN         NaN      NaN      16888      26974
# 2719     1      1        NaN         NaN      NaN      33333      35070
# 2720     1      1        NaN         NaN      NaN        NaN          0
# 2721     2      1        NaN         NaN      NaN        NaN          0
# 2722     6      1        NaN         NaN      NaN        NaN          0
#
#      flea_ch48percent prapor therapist  fence skier peacekeeper mechanic  \
# 0              -45.34   9198       NaN   7358   NaN          84    10302
# 1                   0    NaN       NaN    400   NaN         NaN      NaN
# 2               -3.46  25000     31500  20000   NaN         NaN      NaN
# 3               11.72   2548       NaN   2038   NaN          23     2854
# 4                -6.8   3615       NaN   2892   NaN         NaN      NaN
# ...               ...    ...       ...    ...   ...         ...      ...
# 2718             0.37    NaN       NaN   7200  8820          82      NaN
# 2719            -3.51  20000     25200  16000   NaN         NaN      NaN
# 2720             None    300       378    240   294         NaN      NaN
# 2721                0  29554       NaN  23643   NaN         269    33100
# 2722                0  20255       NaN  16204   NaN         184    22686
#
#      ragman jaeger
# 0       NaN    NaN
# 1       NaN    NaN
# 2       NaN    NaN
# 3       NaN    NaN
# 4       NaN    NaN
# ...     ...    ...
# 2718  11160    NaN
# 2719    NaN    NaN
# 2720    NaN    NaN
# 2721    NaN    NaN
# 2722    NaN  24306
#
# [2723 rows x 18 columns]

# %%
# all_items_df

# %%
# all_items_dict
